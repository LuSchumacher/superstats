# %%
import sys
sys.path.append('../')

import superstats
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 4
#       1 import sys
#       2 sys.path.append('../')
# ----> 4 import superstats
#
# File c:\Users\radevs\Desktop\Projects\superstats\examples\..\superstats\__init__.py:9
#       6 setup()
#       7 del setup
# ----> 9 from . import (
#      10     prior,
#      11     simulation,
#      12     study,
#      13     transition
#      14 )
#
# File c:\Users\radevs\Desktop\Projects\superstats\examples\..\superstats\transition\__init__.py:1
# ----> 1 from .rw import RW
#       2 from .transition import Transition
#       4 __all__ = [
#       5     "RW",
#       6     "Transition"
#       7 ]
#
# File c:\Users\radevs\Desktop\Projects\superstats\examples\..\superstats\transition\rw.py:6
#       4 from superstats.utils.helpers import scaled_sigmoid
#       5 from .transition import Transition
# ...

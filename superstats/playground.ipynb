# %%
import numpy as np
import seaborn as sns

import sys
sys.path.append('../')

import superstats as sup

# %%
prior = sup.prior.JointPrior(
    v=sup.transition.RandomWalk(bounds=(0.0, 6.0)),
    a=sup.transition.RandomWalk(bounds=(0.5, 6.0)),
    ndt=sup.transition.RandomWalk(bounds=(0.0, 2.0), sigma=0.05),
    bias=sup.prior.Prior(dist="beta", a=25.0, b=25.0)
)
